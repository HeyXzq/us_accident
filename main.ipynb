# %%
import pandas as pd

# Load the dataset
data_df = pd.read_csv("US_Accidents_Dec20_Updated.csv")
data_df.info() # show entries, dtypes, memory useage.

# Have a look
data_df.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2906610 entries, 0 to 2906609
# Data columns (total 47 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Severity               int64
#  2   Start_Time             object
#  3   End_Time               object
#  4   Start_Lat              float64
#  5   Start_Lng              float64
#  6   End_Lat                float64
#  7   End_Lng                float64
#  8   Distance(mi)           float64
#  9   Description            object
#  10  Number                 float64
#  11  Street                 object
#  12  Side                   object
#  13  City                   object
#  14  County                 object
#  15  State                  object
#  16  Zipcode                object
#  17  Country                object
#  18  Timezone               object
#  19  Airport_Code           object
#  20  Weather_Timestamp      object
# ...

# %%
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.describe.html
# Basic statistic on Ordinal, Interval and Ratio data.
OIR_columns = ['Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)', 'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Speed(mph)', 'Precipitation(in)']
data_df[OIR_columns].describe() #Exclude Time; Time can be transformed to second/minute/hour/day/month/year separately, but it is no need to do it here.
# Out:
#            Severity     Start_Lat     Start_Lng       End_Lat       End_Lng  \
# count  2.906610e+06  2.906610e+06  2.906610e+06  2.623789e+06  2.623789e+06
# mean   2.288649e+00  3.653027e+01 -9.642676e+01  3.651733e+01 -9.620367e+01
# std    5.541618e-01  5.013964e+00  1.775412e+01  5.016609e+00  1.765971e+01
# min    1.000000e+00  2.455527e+01 -1.246238e+02  2.455527e+01 -1.246238e+02
# 25%    2.000000e+00  3.366453e+01 -1.178232e+02  3.364659e+01 -1.177020e+02
# 50%    2.000000e+00  3.609977e+01 -9.116690e+01  3.605898e+01 -9.105163e+01
# 75%    3.000000e+00  4.037505e+01 -8.085814e+01  4.033133e+01 -8.084679e+01
# max    4.000000e+00  4.900220e+01 -6.711317e+01  4.907500e+01 -6.710924e+01
#
#        Distance(mi)  Temperature(F)  Wind_Chill(F)   Humidity(%)  \
# count  2.906610e+06    2.839386e+06   1.722751e+06  2.835340e+06
# mean   3.980541e-01    6.098873e+01   5.499048e+01  6.537758e+01
# std    1.592556e+00    1.845258e+01   2.219542e+01  2.287854e+01
# ...

# %%
# Basic statistic on Nominal data
data_df.loc[:, ~data_df.columns.isin(OIR_columns)].astype("object").describe() # All the Nominal data can be treated as "object" type for simplicity.
# Out:
#              ID                                        Description     Number  \
# count   2906610                                            2906610  1014938.0
# unique  2906610                                            1484192    41616.0
# top         A-1  A crash has occurred causing no to minimum del...        1.0
# freq          1                                               2709    11882.0
#
#          Street     Side         City       County    State  Zipcode  Country  \
# count   2906610  2906610      2906502      2906610  2906610  2905496  2906610
# unique   175527        3        11789         1729       49   372018        1
# top       I-5 N        R  Los Angeles  Los Angeles       CA    91761       US
# freq      37554  2409662        68411       233648   730744     5185  2906610
#
#         ... Roundabout  Station     Stop Traffic_Calming Traffic_Signal  \
# count   ...    2906610  2906610  2906610         2906610        2906610
# ...
